# %% [markdown]
# # Tital Prediction on Actual Test Set

# %% [markdown]
# **Note:** `datahow_interview_test_targets-TEMPLATE.csv` is a *submission template*, not the real ground truth - every row currently has the same placeholder value (`Y:Titer = 2000`).

# %%
import numpy as np
import pandas as pd
import joblib
import matplotlib.pyplot as plt
from pathlib import Path
from sklearn.metrics import mean_absolute_error, r2_score

# %%
DATA_DIR = "./dataset"
MODELS_DIR = Path("models")

test_exp = pd.read_csv(f"{DATA_DIR}/test_exp_features.csv", index_col="Exp")
feature_cols = [c for c in test_exp.columns if c != "n_days"]

# to be replaced with the actual test file
targets = pd.read_csv(
    f"{DATA_DIR}/datahow_interview_test_targets-TEMPLATE.csv",
    index_col="Exp"
)

print("test_exp:", test_exp.shape)
print(f"Using {len(feature_cols)} features")
# test_exp.head()
# Out:
# test_exp: (20, 68)
# Using 67 features

# %% [markdown]
# ## 1. Load trained models
#
# Load the 7 regressors that were fit on the full training set and persisted with `joblib` in `baseline.ipynb`.

# %%
model_files = {
    "Linear Regression": "Linear_Regression.joblib",
    "Multiple Linear Regression": "Multiple_Linear_Regression.joblib",
    "Ridge": "Ridge.joblib",
    "PLS (5 comp)": "PLS_5_comp.joblib",
    "RandomForest": "RandomForest.joblib",
    "GradientBoosting": "GradientBoosting.joblib",
    "XGBoost": "XGBoost.joblib",
}
models = {name: joblib.load(MODELS_DIR / fname) for name, fname in model_files.items()}
list(models.keys())
# Out:
# ['Linear Regression',
#  'Multiple Linear Regression',
#  'Ridge',
#  'PLS (5 comp)',
#  'RandomForest',
#  'GradientBoosting',
#  'XGBoost']

# %% [markdown]
# ## 2. Generate predictions
#
# - Only the simple `Linear Regression` model was trained on a single feature (`VCD_time_to_peak`)
# - Every other model was trained on the full 67-feature set, in the same column order as the training data.

# %%
X_full = test_exp[feature_cols]
X_single = test_exp[["VCD_time_to_peak"]]

predictions = {}
for name, model in models.items():
    X_input = X_single if name == "Linear Regression" else X_full
    predictions[name] = model.predict(X_input).ravel()

pred_df = pd.DataFrame(predictions, index=test_exp.index)
pred_df
# Out:
# /home/cds/rketkaew/github/datahow-task/.venv/lib/python3.13/site-packages/sklearn/utils/validation.py:2820: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# /home/cds/rketkaew/github/datahow-task/.venv/lib/python3.13/site-packages/sklearn/utils/validation.py:2820: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# /home/cds/rketkaew/github/datahow-task/.venv/lib/python3.13/site-packages/sklearn/utils/validation.py:2820: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# /home/cds/rketkaew/github/datahow-task/.venv/lib/python3.13/site-packages/sklearn/utils/validation.py:2820: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# /home/cds/rketkaew/github/datahow-task/.venv/lib/python3.13/site-packages/sklearn/utils/validation.py:2820: UserWarning: X has feature names, but RandomForestRegressor was fitted without feature names
#   warnings.warn(
# /home/cds/rketkaew/github/datahow-task/.venv/lib/python3.13/site-packages/sklearn/utils/validation.py:2820: UserWarning: X has feature names, but GradientBoostingRegressor was fitted without feature names
#   warnings.warn(
#              Linear Regression  Multiple Linear Regression        Ridge  \
# Exp
# Test Exp 1         2289.087043                 1061.592795  2244.114978
# Test Exp 2         1592.958634                 2900.113900  3141.410235
# Test Exp 3         3333.279656                 1529.447957  1691.717985
# Test Exp 4         1244.894430                 1093.657678  3237.390518
# Test Exp 5         2637.151247                 2700.222534  2966.109617
# Test Exp 6         1244.894430                 2017.469478  1986.081918
# Test Exp 7         2637.151247                 2292.121234  3485.188230
# Test Exp 8          548.766021                 -431.155307  1905.684499
# Test Exp 9          896.830225                -1391.552768  -542.000928
# Test Exp 10        2289.087043                 1812.041899  1182.515743
# Test Exp 11        2985.215451                  763.023458  1606.849953
# Test Exp 12        1941.022838                 2361.430966  2843.098846
# Test Exp 13        2985.215451                 1395.572187  2585.900532
# Test Exp 14        2289.087043                 3577.773450  2709.113706
# Test Exp 15        1592.958634                 2834.108370  1136.540338
# Test Exp 16        2289.087043                 3177.320099  3374.312613
# Test Exp 17        1941.022838                 2107.471922  1986.880015
# Test Exp 18        1941.022838                 2628.215662  2904.262240
# Test Exp 19        1244.894430                  407.974633  1881.777399
# Test Exp 20        2289.087043                 1919.884683  2324.145920
#
#              PLS (5 comp)  RandomForest  GradientBoosting      XGBoost
# Exp
# Test Exp 1    2448.794105   2397.445871       2509.959303  2312.313721
# Test Exp 2    3272.292260   2791.590801       2665.466782  1931.755371
# Test Exp 3    1629.647278   1781.571535       1566.297806  1496.013916
# Test Exp 4    3279.233141   2121.369113       1784.833250  1813.078613
# Test Exp 5    2947.580346   2861.334465       2495.654484  2489.583984
# Test Exp 6    1875.963297   1425.924012       1014.158288  1018.660950
# Test Exp 7    3370.437716   2855.903455       2447.467612  2603.745605
# Test Exp 8    2013.974128   2031.618599       1698.440836  1412.079712
# Test Exp 9    -405.107920    553.342796        590.504182   524.285400
# Test Exp 10   1125.425085   1778.582500       1942.382288  2321.414062
# Test Exp 11   1459.347228   1633.697427       1662.911030  1729.554077
# Test Exp 12   2980.131226   2273.833000       2145.704520  2144.406494
# Test Exp 13   2799.384303   2108.752057       2035.096804  1917.907837
# Test Exp 14   2610.939619   2206.983217       2224.022143  2004.328369
# Test Exp 15   1163.935128   1610.829738       1610.063221  1780.010742
# Test Exp 16   3362.234475   2820.243582       2758.507961  2657.791992
# Test Exp 17   1982.023551   2185.871888       2179.781007  1971.596558
# Test Exp 18   2961.778162   2656.940082       3224.521298  3177.126221
# Test Exp 19   2053.175138   1221.410994       1004.135682  1812.208984
# Test Exp 20   2353.380566   1999.844819       1783.937028  2142.695801

# %% [markdown]
# ## 3. Compare against the target template
#
# Note: the comparison and metrics below only illustrate the workflow; re-run this section once the actual test targets are available.

# %%
comparison = pred_df.copy()
comparison["Y:Titer (template)"] = targets["Y:Titer"]
comparison
# Out:
#              Linear Regression  Multiple Linear Regression        Ridge  \
# Exp
# Test Exp 1         2289.087043                 1061.592795  2244.114978
# Test Exp 2         1592.958634                 2900.113900  3141.410235
# Test Exp 3         3333.279656                 1529.447957  1691.717985
# Test Exp 4         1244.894430                 1093.657678  3237.390518
# Test Exp 5         2637.151247                 2700.222534  2966.109617
# Test Exp 6         1244.894430                 2017.469478  1986.081918
# Test Exp 7         2637.151247                 2292.121234  3485.188230
# Test Exp 8          548.766021                 -431.155307  1905.684499
# Test Exp 9          896.830225                -1391.552768  -542.000928
# Test Exp 10        2289.087043                 1812.041899  1182.515743
# Test Exp 11        2985.215451                  763.023458  1606.849953
# Test Exp 12        1941.022838                 2361.430966  2843.098846
# Test Exp 13        2985.215451                 1395.572187  2585.900532
# Test Exp 14        2289.087043                 3577.773450  2709.113706
# Test Exp 15        1592.958634                 2834.108370  1136.540338
# Test Exp 16        2289.087043                 3177.320099  3374.312613
# Test Exp 17        1941.022838                 2107.471922  1986.880015
# Test Exp 18        1941.022838                 2628.215662  2904.262240
# Test Exp 19        1244.894430                  407.974633  1881.777399
# Test Exp 20        2289.087043                 1919.884683  2324.145920
#
#              PLS (5 comp)  RandomForest  GradientBoosting      XGBoost  \
# Exp
# Test Exp 1    2448.794105   2397.445871       2509.959303  2312.313721
# Test Exp 2    3272.292260   2791.590801       2665.466782  1931.755371
# Test Exp 3    1629.647278   1781.571535       1566.297806  1496.013916
# Test Exp 4    3279.233141   2121.369113       1784.833250  1813.078613
# Test Exp 5    2947.580346   2861.334465       2495.654484  2489.583984
# Test Exp 6    1875.963297   1425.924012       1014.158288  1018.660950
# Test Exp 7    3370.437716   2855.903455       2447.467612  2603.745605
# Test Exp 8    2013.974128   2031.618599       1698.440836  1412.079712
# Test Exp 9    -405.107920    553.342796        590.504182   524.285400
# Test Exp 10   1125.425085   1778.582500       1942.382288  2321.414062
# Test Exp 11   1459.347228   1633.697427       1662.911030  1729.554077
# Test Exp 12   2980.131226   2273.833000       2145.704520  2144.406494
# Test Exp 13   2799.384303   2108.752057       2035.096804  1917.907837
# Test Exp 14   2610.939619   2206.983217       2224.022143  2004.328369
# Test Exp 15   1163.935128   1610.829738       1610.063221  1780.010742
# Test Exp 16   3362.234475   2820.243582       2758.507961  2657.791992
# Test Exp 17   1982.023551   2185.871888       2179.781007  1971.596558
# Test Exp 18   2961.778162   2656.940082       3224.521298  3177.126221
# Test Exp 19   2053.175138   1221.410994       1004.135682  1812.208984
# Test Exp 20   2353.380566   1999.844819       1783.937028  2142.695801
#
#              Y:Titer (template)
# Exp
# Test Exp 1                 2000
# Test Exp 2                 2000
# Test Exp 3                 2000
# Test Exp 4                 2000
# Test Exp 5                 2000
# Test Exp 6                 2000
# Test Exp 7                 2000
# Test Exp 8                 2000
# Test Exp 9                 2000
# Test Exp 10                2000
# Test Exp 11                2000
# Test Exp 12                2000
# Test Exp 13                2000
# Test Exp 14                2000
# Test Exp 15                2000
# Test Exp 16                2000
# Test Exp 17                2000
# Test Exp 18                2000
# Test Exp 19                2000
# Test Exp 20                2000

# %%
y_true = targets["Y:Titer"].loc[pred_df.index]

metrics = []
for name in pred_df.columns:
    y_pred = pred_df[name]
    metrics.append(
        {
            "model": name,
            "MAE": mean_absolute_error(y_true, y_pred),
            "RMSE": np.sqrt(np.mean((y_true - y_pred) ** 2)),
            "R2": r2_score(y_true, y_pred),
        }
    )

metrics_df = pd.DataFrame(metrics).sort_values("MAE").reset_index(drop=True)
metrics_df
# Out:
#                         model         MAE         RMSE   R2
# 0                     XGBoost  422.312683   574.845862  0.0
# 1                RandomForest  465.334115   589.673549  0.0
# 2            GradientBoosting  501.425915   629.280686  0.0
# 3           Linear Regression  591.709147   718.475148  0.0
# 4                       Ridge  748.950026   963.057223  0.0
# 5                PLS (5 comp)  781.105077   969.734868  0.0
# 6  Multiple Linear Regression  921.788020  1230.905114  0.0

# %%
plt.figure(figsize=(7, 4))
plt.bar(metrics_df["model"], metrics_df["MAE"], color="slateblue")
plt.ylabel("MAE vs. template placeholder Y:Titer")
plt.title("Prediction comparison against target template (placeholder values)")
plt.xticks(rotation=15)
plt.tight_layout()
plt.show()
